# %%
from sklearn.neural_network import MLPClassifier

import numpy as np

from sklearn.impute import SimpleImputer

from sklearn.model_selection import train_test_split, cross_validate

from sklearn.svm import SVC

from sklearn.metrics import accuracy_score, classification_report

import matplotlib.pyplot as plt

# %matplotlib inline

input_feature_matrix = np.genfromtxt('../RESOURCE/processed_data.csv', delimiter = ',', dtype = float, skip_header = 1, usecols = range(19))

output = np.genfromtxt('../RESOURCE/processed_data.csv', delimiter = ',', dtype = float, skip_header = 1, usecols = 19)

input_feature_matrix = SimpleImputer(missing_values=np.nan, strategy='mean').fit(input_feature_matrix).transform(input_feature_matrix)

trainX, testX, trainY, testY = train_test_split(input_feature_matrix, output, train_size = 0.85, test_size = 0.15, random_state = 1)

model = MLPClassifier().fit(trainX, trainY)

predY = model.predict(testX)

print("Accuracy {:.2f}".format(accuracy_score(predY, testY)))

print(classification_report(testY, predY))

modelMLPClassifier = cross_validate(model,input_feature_matrix,output,cv = 5)

plt.plot(modelMLPClassifier['test_score'], "p")
# Out:
# Iteration 1, loss = inf
# Iteration 2, loss = inf
# Iteration 3, loss = 2.43723211
# Iteration 4, loss = 0.78929134
# Iteration 5, loss = 0.55228115
# Iteration 6, loss = 0.64222918
# Iteration 7, loss = 0.57557773
# Iteration 8, loss = 0.58500290
# Iteration 9, loss = 0.52886564
# Iteration 10, loss = 0.70160360
# Iteration 11, loss = 0.97236736
# Iteration 12, loss = 1.62923471
# Iteration 13, loss = 0.88146512
# Iteration 14, loss = 0.80618530
# Iteration 15, loss = 0.70014336
# Iteration 16, loss = 0.73108441
# Iteration 17, loss = 0.79742138
# Iteration 18, loss = 0.86513037
# Iteration 19, loss = 0.80389778
# Iteration 20, loss = 0.67343086
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Accuracy 0.81
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.92      0.88       798
#          1.0       0.66      0.50      0.57       259
#
#     accuracy                           0.81      1057
#    macro avg       0.76      0.71      0.73      1057
# weighted avg       0.80      0.81      0.81      1057
#
# Iteration 1, loss = 2.95308238
# Iteration 2, loss = 1.28958773
# Iteration 3, loss = 0.85564179
# Iteration 4, loss = 1.10832331
# Iteration 5, loss = 1.24187632
# Iteration 6, loss = 0.80168920
# Iteration 7, loss = 1.00829523
# Iteration 8, loss = 0.49557580
# Iteration 9, loss = 0.65753758
# Iteration 10, loss = 0.72808102
# Iteration 11, loss = 0.96013541
# Iteration 12, loss = 0.57261730
# Iteration 13, loss = 0.79138272
# Iteration 14, loss = 0.68729223
# Iteration 15, loss = 0.49629900
# Iteration 16, loss = 1.90665957
# Iteration 17, loss = 0.61960635
# Iteration 18, loss = 0.81009139
# Iteration 19, loss = 0.57179438
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = inf
# Iteration 2, loss = 3.42145986
# Iteration 3, loss = 1.36573902
# Iteration 4, loss = 0.80485590
# Iteration 5, loss = 0.50923974
# Iteration 6, loss = 0.94133011
# Iteration 7, loss = 0.91712566
# Iteration 8, loss = 1.04862705
# Iteration 9, loss = 0.56405617
# Iteration 10, loss = 0.96280909
# Iteration 11, loss = 0.96430821
# Iteration 12, loss = 0.90608833
# Iteration 13, loss = 0.52985636
# Iteration 14, loss = 0.83791796
# Iteration 15, loss = 0.71414159
# Iteration 16, loss = 0.83697604
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss